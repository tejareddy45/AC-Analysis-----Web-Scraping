# %% [markdown]
# ## analyzing and identifying the best air conditioners available in flipkart based on their features and customer ratings and reviews.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\ramya vemuri\Downloads\AC_Cleaning.csv")

# %%
data
# Out:
#      Unnamed: 0      Brand  Cooling_Capacity(Ton)  Star_Rating  \
# 0             0        IFB                    1.0            3
# 1             1    CARRIER                    1.5            3
# 2             2     Godrej                    1.5            3
# 3             3     Godrej                    1.4            3
# 4             4       MarQ                    1.5            3
# ..          ...        ...                    ...          ...
# 471         471     Godrej                    2.0            3
# 472         472  Panasonic                    0.8            3
# 473         473  Panasonic                    1.0            3
# 474         474       Blue                    2.0            3
# 475         475         LG                    1.5            5
#
#      Annual_power_usage  Average_Room_Size  Warranty  Price  Ratings  \
# 0                655.74               90.0       0.0  29990      3.9
# ...

# %%
data=data.drop(columns = ["Unnamed: 0"])

# %%
data
# Out:
#          Brand  Cooling_Capacity(Ton)  Star_Rating  Annual_power_usage  \
# 0          IFB                    1.0            3              655.74
# 1      CARRIER                    1.5            3              964.10
# 2       Godrej                    1.5            3              966.34
# 3       Godrej                    1.4            3              905.88
# 4         MarQ                    1.5            3              952.69
# ..         ...                    ...          ...                 ...
# 471     Godrej                    2.0            3             1183.20
# 472  Panasonic                    0.8            3              519.64
# 473  Panasonic                    1.0            3              676.64
# 474       Blue                    2.0            3             1261.37
# 475         LG                    1.5            5                0.00
#
#      Average_Room_Size  Warranty  Price  Ratings  no_of_rating  Reviews
# ...

# %% [markdown]
# ### **Cooling Capacity (Ton)**:
# #### This indicates the efficiency of the air conditioner in cooling a room. Higher tonnage is generally better for larger rooms.
# ### **Star Rating**:
# #### This shows the energy efficiency of the AC. A higher star rating (e.g., 5 stars) means better energy efficiency, which can reduce long-term operating costs.
# ### **Annual Power Usage (kWh)**:
# #### This is an important factor to consider, as it directly affects electricity consumption and running costs. Lower values are more efficient.
# ### **Average Room Size**:
# #### This can be used to compare the suitability of the air conditioner for specific room sizes.
# ### **Warranty**:
# #### A longer warranty indicates better confidence in the product's durability.
# ### **Price**:
# #### Helps to compare the value for money, keeping in mind the other features and performance.
# ### **Ratings**:
# #### The average customer rating can indicate product quality and user satisfaction.
# ### **Number of Ratings**:
# #### A higher number of ratings suggests the product is popular and has been tried by many users.
# ### **Reviews**:
# #### The sentiment expressed in reviews can provide insights into the air conditioner's real-world performance.

# %% [markdown]
# ### Statistical Analysis(Non-Viz) :

# %%
data.describe()
# Out:
#        Cooling_Capacity(Ton)  Star_Rating  Annual_power_usage  \
# count             476.000000   476.000000          476.000000
# mean                1.436134     3.684874          848.909832
# std                 0.331118     0.902314          235.929687
# min                 0.800000     2.000000            0.000000
# 25%                 1.275000     3.000000          700.762500
# 50%                 1.500000     3.000000          851.590000
# 75%                 1.500000     5.000000         1002.310000
# max                 2.000000     5.000000         1281.640000
#
#        Average_Room_Size    Warranty         Price     Ratings  no_of_rating  \
# count         476.000000  476.000000    476.000000  476.000000    476.000000
# mean          143.476891    1.065126  40626.119748    4.048529  10757.470588
# std           147.611294    1.230303   7945.536575    0.103710  10026.097166
# min             0.000000    0.000000  26490.000000    3.500000     64.000000
# ...

# %% [markdown]
# ### Identify High Cooling Capacity:
# #### For larger rooms, air conditioners with higher cooling capacities (higher tonnage, such as 1.5 ton or 2 ton) are more suitable. We will identify these based on the cooling capacity.

# %%
top_ac = data.sort_values(by=["Cooling_Capacity(Ton)"], ascending=[False])

# %%
top_ac.head()
# Out:
#        Brand  Cooling_Capacity(Ton)  Star_Rating  Annual_power_usage  \
# 113     Blue                    2.0            3             1261.37
# 329   Godrej                    2.0            3             1183.20
# 84    Godrej                    2.0            5              916.68
# 167  SAMSUNG                    2.0            3             1145.22
# 82     Lloyd                    2.0            5              970.29
#
#      Average_Room_Size  Warranty  Price  Ratings  no_of_rating  Reviews
# 113              175.5       1.0  48990      4.0          5266      456
# 329              175.5       5.0  42990      4.0         11016      812
# 84               175.5       5.0  50990      3.9          1063       65
# 167              175.5       1.0  48990      4.1          2440      206
# 82               175.5       1.0  52990      4.1          8803     1193

# %% [markdown]
# ### top Ac's based on ratings.

# %%
top_ac = data.sort_values(by=["Ratings"], ascending=[False])

# %%
top_ac.head()
# Out:
#          Brand  Cooling_Capacity(Ton)  Star_Rating  Annual_power_usage  \
# 283  Panasonic                    1.5            5              846.85
# 230       MarQ                    1.5            3             1213.10
# 475         LG                    1.5            5                0.00
# 445     Daikin                    1.5            3                0.00
# 416     Daikin                    1.5            5              756.78
#
#      Average_Room_Size  Warranty  Price  Ratings  no_of_rating  Reviews
# 283              130.5       1.0  44934      4.5           153       23
# 230              130.5       1.0  27984      4.4           190       26
# 475              520.0       1.0  34419      4.3          4292      423
# 445             1752.0       1.0  41500      4.3           542       46
# 416              130.5       1.0  71200      4.3           390       56

# %% [markdown]
# ### top Ac's based on Star_Rating.

# %%
top_ac = data.sort_values(by=["Star_Rating"], ascending=[False])

# %%
top_ac.head()
# Out:
#          Brand  Cooling_Capacity(Ton)  Star_Rating  Annual_power_usage  \
# 238  Panasonic                    1.5            5              774.19
# 110    CARRIER                    1.0            5              536.20
# 212       Blue                    1.5            5              770.98
# 216  Panasonic                    1.0            5              531.41
# 217  Panasonic                    1.5            5              774.19
#
#      Average_Room_Size  Warranty  Price  Ratings  no_of_rating  Reviews
# 238              130.5       1.0  44990      4.1         24837     2508
# 110               90.0       0.0  35490      4.0         14872     1254
# 212              130.5       1.0  45990      4.0          5266      456
# 216               90.0       0.0  40990      4.1           473       56
# 217              130.5       1.0  44990      4.1         24837     2508

# %% [markdown]
# ### top Ac's Annual_power_usage.

# %%
top_ac = data.sort_values(by=["Annual_power_usage"], ascending=[False])

# %%
top_ac.head()
# Out:
#      Brand  Cooling_Capacity(Ton)  Star_Rating  Annual_power_usage  \
# 23    MarQ                    2.0            3             1281.64
# 92   Haier                    2.0            3             1276.55
# 140  Haier                    2.0            3             1276.55
# 130  Haier                    2.0            3             1276.55
# 365   Blue                    2.0            3             1261.37
#
#      Average_Room_Size  Warranty  Price  Ratings  no_of_rating  Reviews
# 23               175.5       1.0  36990      4.1         15763     1658
# 92               175.5       5.0  49990      4.0          1541      185
# 140              175.5       5.0  52990      4.0          1541      185
# 130              175.5       5.0  52990      4.0          1541      185
# 365              175.5       1.0  48990      4.0          5266      456

# %% [markdown]
# ### top Ac's Brand.

# %%
top_ac = data.sort_values(by=["Brand"], ascending=[False])

# %%
top_ac.head(4)
# Out:
#       Brand  Cooling_Capacity(Ton)  Star_Rating  Annual_power_usage  \
# 54   realme                    1.0            3              675.18
# 91   realme                    1.5            5              770.08
# 165  realme                    1.0            3              663.61
# 49   realme                    1.5            5              767.34
#
#      Average_Room_Size  Warranty  Price  Ratings  no_of_rating  Reviews
# 54                90.0       0.0  27490      4.1          1495      190
# 91               130.5       1.0  65999      4.2          1578      175
# 165               90.0       0.0  27490      4.2          1578      175
# 49               130.5       1.0  32999      4.1          1495      190

# %% [markdown]
# ### top Ac's Price.

# %%
top_ac = data.sort_values(by=["Price"], ascending=[False])

# %%
top_ac.head()
# Out:
#        Brand  Cooling_Capacity(Ton)  Star_Rating  Annual_power_usage  \
# 168  SAMSUNG                    2.0            3             1145.22
# 255  CARRIER                    2.0            3             1257.12
# 418  SAMSUNG                    1.5            5              749.48
# 416   Daikin                    1.5            5              756.78
# 68    realme                    1.5            5              770.08
#
#      Average_Room_Size  Warranty  Price  Ratings  no_of_rating  Reviews
# 168              175.5       1.0  80990      4.2           740       61
# 255              175.5       1.0  78500      4.0         14872     1254
# 418              130.5       1.0  76990      4.1          2440      206
# 416              130.5       1.0  71200      4.3           390       56
# 68               130.5       1.0  65999      4.2          1578      175

# %% [markdown]
# ### top Ac's no_of_rating.

# %%
top_ac = data.sort_values(by=["no_of_rating"], ascending=[False])

# %%
top_ac.head()
# Out:
#     Brand  Cooling_Capacity(Ton)  Star_Rating  Annual_power_usage  \
# 419    LG                    1.5            3              852.44
# 161    LG                    2.0            3             1232.78
# 392    LG                    1.5            5              685.26
# 209    LG                    1.5            5              818.81
# 98     LG                    1.5            5              685.26
#
#      Average_Room_Size  Warranty  Price  Ratings  no_of_rating  Reviews
# 419              130.5       1.0  44500      4.1         40617     3635
# 161              175.5       1.0  54990      4.1         40617     3635
# 392              130.5       1.0  49990      4.1         40617     3635
# 209              130.5       1.0  50300      4.1         40617     3635
# 98               130.5       1.0  42990      4.1         40617     3635

# %% [markdown]
# ### Finding the ACs with the lowest annual power usage

# %%
low_power_usage_ac = data[data['Annual_power_usage'] < data['Annual_power_usage'].quantile(0.25)]

# %%
low_power_usage_ac
# Out:
#          Brand  Cooling_Capacity(Ton)  Star_Rating  Annual_power_usage  \
# 0          IFB                    1.0            3              655.74
# 8       Godrej                    1.0            3              694.03
# 12        MarQ                    1.0            3              675.18
# 19       Lloyd                    1.0            3              698.48
# 38       ONIDA                    1.0            3              674.08
# ..         ...                    ...          ...                 ...
# 462  Panasonic                    0.8            3              519.64
# 463  Panasonic                    1.0            3              676.64
# 472  Panasonic                    0.8            3              519.64
# 473  Panasonic                    1.0            3              676.64
# 475         LG                    1.5            5                0.00
#
#      Average_Room_Size  Warranty  Price  Ratings  no_of_rating  Reviews
# ...

# %%
data
# Out:
#          Brand  Cooling_Capacity(Ton)  Star_Rating  Annual_power_usage  \
# 0          IFB                    1.0            3              655.74
# 1      CARRIER                    1.5            3              964.10
# 2       Godrej                    1.5            3              966.34
# 3       Godrej                    1.4            3              905.88
# 4         MarQ                    1.5            3              952.69
# ..         ...                    ...          ...                 ...
# 471     Godrej                    2.0            3             1183.20
# 472  Panasonic                    0.8            3              519.64
# 473  Panasonic                    1.0            3              676.64
# 474       Blue                    2.0            3             1261.37
# 475         LG                    1.5            5                0.00
#
#      Average_Room_Size  Warranty  Price  Ratings  no_of_rating  Reviews
# ...

# %% [markdown]
# # **Data_Visualization**

# %% [markdown]
# ### Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Price Distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Price'], kde=True, color='blue')
plt.title('Distribution of AC Prices')
plt.xlabel('Price (in INR)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\ramya vemuri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2. Ratings Distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Ratings'], kde=True, color='green')
plt.title('Distribution of AC Ratings')
plt.xlabel('Customer Ratings')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\ramya vemuri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 3. Cooling Capacity Distribution

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x=data['Cooling_Capacity(Ton)'], palette='viridis')
plt.title('Cooling Capacity Distribution')
plt.xlabel('Cooling Capacity (Ton)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Average Room Size Distribution

# %%
sns.histplot(data['Average_Room_Size'], kde=True, bins=20, color='green')
plt.title("Average Room Size Distribution")
plt.show()
# Out:
# C:\Users\ramya vemuri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Univariate Analysis Summary statistics for numerical and categorical columns Distributions

# %%
# Univariate Analysis - Summary statistics for numerical columns
numerical_summary =data.describe()

# Frequency counts for categorical column
categorical_summary = data['Brand'].value_counts()

# Visualizations for Univariate Analysis
plt.figure(figsize=(15, 10))
for i, column in enumerate(data.select_dtypes(include=['float64', 'int64']).columns, 1):
    plt.subplot(3, 3, i)
    sns.histplot(data[column], kde=True, bins=20, color='skyblue')
    plt.title(f'Distribution of {column}')

plt.tight_layout()
plt.show()

# Output univariate summary
numerical_summary, categorical_summary
# Out:
# C:\Users\ramya vemuri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ramya vemuri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ramya vemuri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ### Ratings by Star Rating Distribution. (boxplot)

# %%
sns.boxplot(data=data, x='Star_Rating', y='Ratings', palette='muted')
plt.title("Ratings by Star Rating")
plt.show()

# %% [markdown]
# ### Observations:
#
# ---> 2-Star Rating: There is only one data point, so no box is formed.
#
# ---> 3-Star Rating: The ratings are more spread out, with a median around 4.0.
#
# ---> 4-Star Rating: The ratings are slightly more concentrated, with a median around 4.1.
#
# ---> 5-Star Rating: The ratings are more concentrated, with a median around 4.3.

# %% [markdown]
# ### Price by Star Rating Distribution.(boxplot)

# %%
sns.boxplot(data=data, x='Star_Rating', y='Price', palette='coolwarm')
plt.title("Price by Star Rating")
plt.show()

# %% [markdown]
# ### Observations from the  above plot:
# --->  2-Star Rating: There is only one data point, so no box is formed.
#
# ---> 3-Star Rating: Prices are more spread out, with a median around 40,000 INR.
#
# ---> 4-Star Rating: Prices are even more spread out, with many outliers.
#
# ---> 5-Star Rating: Prices are more concentrated, with a median around 50,000 INR.

# %% [markdown]
# ### Price by Cooling Capacity Distribution (boxplot)

# %%
sns.boxplot(data=data, x='Cooling_Capacity(Ton)', y='Price', palette='Spectral')
plt.title("Price by Cooling Capacity")
plt.show()

# %% [markdown]
# ### Observations:
#
# ---> Cooling Capacities: The plot categorizes cooling capacities into several bins: approximately 0.8, 1.0, 1.2, 1.4, 1.5, 1.8, and 2.0 tons.
#
# ---> Price Distribution: The price distribution varies significantly across different cooling capacities.
#
# ---> Outliers: There are several outliers, especially for cooling capacities of 1.0, 1.5, and 2.0 tons.
#
# ---> Median Price: The median price tends to increase with higher cooling capacities.

# %%
brand_avg_price = data.groupby('Brand')['Price'].mean().sort_values()
print(brand_avg_price)
# Out:
# Brand
# CANDY        27490.000000
# MITASHI      29500.000000
# MOTOROLA     29990.000000
# MarQ         30405.666667
# Admiral      30490.000000
# Hisense      32490.000000
# ONIDA        35240.000000
# Voltas       38323.523810
# Panasonic    38361.982036
# Whirlpool    39225.400000
# CARRIER      39756.200000
# Lloyd        40079.421053
# IFB          40378.000000
# Godrej       40383.902439
# Hitachi      41153.166667
# realme       41661.166667
# Blue         44512.633803
# Daikin       45414.875000
# Haier        45606.600000
# LG           46496.583333
# Midea        50129.666667
# SAMSUNG      53787.875000
# Name: Price, dtype: float64

# %% [markdown]
# ### Average Price by Brand Distribution.(plot)

# %%
brand_avg_price.plot(kind='bar', color='skyblue', figsize=(12, 6))
plt.title("Average Price by Brand")
plt.xlabel("Brand")
plt.ylabel("Average Price")
plt.savefig('Average Price by Brand', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ### Avearge Ratings by Brand Distributions. (plot)

# %%
avg_ratings_brand = data.groupby('Brand')['Ratings'].mean().sort_values()
avg_ratings_brand.plot(kind='bar', color='purple', figsize=(12, 6))
plt.title("Average Ratings by Brand")
plt.xlabel("Brand")
plt.ylabel("Average Ratings")
plt.show()

# %%
top_5_brands = data['Brand'].value_counts().head(5)
print(top_5_brands)
# Out:
# Brand
# Panasonic    167
# Blue          71
# Godrej        41
# CARRIER       40
# IFB           31
# Name: count, dtype: int64

# %% [markdown]
# ### Observations:
#
# Brands like SAMSUNG and Midea have higher average prices compared to other brands.
#
# Brands like CANDY and MITASHI have lower average prices.

# %% [markdown]
# ### Count of Air Conditions by Star Rating Distributions (countplot)

# %%
sns.countplot(data=data, x="Star_Rating", palette="pastel")
plt.title("Count of Air Conditioners by Star Rating")
plt.show()

# %% [markdown]
# ### Observations:
# ---> 3-Star Rating: The majority of air conditioners have a 3-star rating, with a count close to 300.
#
# ---> 2-Star Rating: There are very few air conditioners with a 2-star rating.
#
# ---> 4-Star Rating: The count of air conditioners with a 4-star rating is significantly lower than those with a 3-star rating.
#
# ---> 5-Star Rating: The count of air conditioners with a 5-star rating is higher than those with a 4-star rating but lower than those with a 3-star rating.

# %% [markdown]
# ### Average Warranty Duration by Brand Distributions (plot)

# %%
brand_warranty = data.groupby('Brand')['Warranty'].mean().sort_values()
brand_warranty.plot(kind='bar', color='orange', figsize=(12, 6))
plt.title("Average Warranty Duration by Brand")
plt.xlabel("Brand")
plt.ylabel("Warranty Duration (Years)")
plt.savefig('Average Warranty Duration by Brand.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ### Observations:
# Godrej has a significantly higher average warranty duration compared to the others, indicating a notable difference in warranty policies among the brands.

# %% [markdown]
# ### 2. Bivariate Analysis:

# %% [markdown]
# ### 1. Price vs Ratings (Scatter Plot)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Price', y='Ratings', data=data, color='green')
plt.title('Price vs Ratings')
plt.xlabel('Price (in INR)')
plt.ylabel('Ratings')
plt.show()

# %% [markdown]
# ### 2.Cooling Capacity vs Annual Power Usage (Scatter Plot)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Cooling_Capacity(Ton)', y='Annual_power_usage', data=data, color='purple')
plt.title('Cooling Capacity vs Annual Power Usage')
plt.xlabel('Cooling Capacity (Ton)')
plt.ylabel('Annual Power Usage (kWh)')
plt.savefig('Cooling Capacity vs Annual Power Usage.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ### Price vs. Ratings (Hue: Star Rating), Price vs. Cooling Capacity (Hue: Star Rating) Distributions (scatterplot)

# %%
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
sns.scatterplot(data=data, x="Ratings", y="Price", hue="Star_Rating", palette="viridis", alpha=0.7)
plt.title("Price vs. Ratings (Hue: Star Rating)")
plt.xlabel("Ratings")
plt.ylabel("Price")
plt.subplot(1, 2, 2)
sns.scatterplot(data=data, x="Cooling_Capacity(Ton)", y="Price", hue="Star_Rating", palette="viridis", alpha=0.7)
plt.title("Price vs. Cooling Capacity (Hue: Star Rating)")
plt.xlabel("Cooling Capacity (Ton)")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ### **Left Plot**:
# Price vs. Ratings (Hue: Star Rating)
#
# ### **X-axis**:
# Ratings (ranging from approximately 3.6 to 4.4)
#
# ### **Y-axis**:
# Price (ranging from 30,000 to 80,000)
#
# ### **Hue**:
# Star Rating (2, 3, 4, 5)
#
# ### **Description**:
# This scatter plot shows the relationship between the ratings of air conditioners and their prices. Each point represents an air conditioner, with the color indicating its star rating. The plot reveals that higher-rated air conditioners (with ratings around 4.0 to 4.4) are spread across a wide range of prices, but there is no clear trend indicating that higher ratings correlate with higher prices.

# %% [markdown]
# ### **Right Plot**:
# Price vs. Cooling Capacity (Hue: Star Rating)
#
# ### **X-axis**:
# Cooling Capacity (Ton) (ranging from 0.8 to 2.0)
#
# ### **Y-axis**:
# Price (ranging from 30,000 to 80,000)
#
# ### **Hue**:
# Star Rating (2, 3, 4, 5)
#
# ### **Description**:
# This scatter plot shows the relationship between the cooling capacity of air conditioners and their prices. Each point represents an air conditioner, with the color indicating its star rating. The plot reveals that air conditioners with higher cooling capacities (around 1.4 to 2.0 tons) tend to have a wider range of prices. There is no clear trend indicating that higher cooling capacity correlates with higher prices.

# %% [markdown]
# ### Cooling_Capacity(Ton) vs Price Distributions (scatterplot)

# %%
sns.scatterplot(data=data, x="Cooling_Capacity(Ton)", y="Price", hue="Star_Rating", palette="viridis", alpha=0.7)
plt.title("Cooling Capacity vs. Price")
plt.show()

# %% [markdown]
# ### Observations:
#
# ---> The scatter plot shows the relationship between the cooling capacity of air conditioners and their prices.
#
# ---> Each point represents an air conditioner, with its position determined by its cooling capacity and price.
#
# ---> The color of the points indicates the star rating of the air conditioner, with blue representing lower star ratings and red representing higher star ratings.
#
# ---> The plot suggests that air conditioners with higher cooling capacities (around 2.0 tons) tend to have higher prices.
#
# ---> There is a clustering of prices around certain cooling capacities (e.g., 1.0 ton, 1.4 tons, and 2.0 tons).
#
# ---> Higher star ratings (4 and 5 stars) are more frequently associated with higher prices.

# %% [markdown]
# ### Price vs. Annual Power Usage Distributions (Scatterplot)

# %%
sns.scatterplot(data=data, x="Annual_power_usage", y="Price", hue="Star_Rating", palette="coolwarm", alpha=0.7)
plt.title("Price vs. Annual Power Usage")
plt.savefig('Price vs. Annual Power Usage.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ### Observations:
#
# ---> This scatter plot shows the relationship between the price of air conditioners and their annual power usage.
#
# ---> Each point represents an air conditioner, with its position determined by its annual power usage and price.
#
# ---> The color of the points indicates the star rating of the air conditioner, with blue representing lower star ratings and red representing higher star ratings.
#
# ---> The plot suggests that there is no clear linear relationship between price and annual power usage. However, higher star ratings (red points) tend to cluster around lower power usage values, indicating better energy efficiency.

# %% [markdown]
# ### Number of Ratings vs. Price Distributions (scatterplot)

# %%
sns.scatterplot(data=data, x="Price", y="no_of_rating", hue="Star_Rating", palette="viridis", alpha=0.7)
plt.title("Number of Ratings vs. Price")
plt.show()

# %% [markdown]
# ### Observations:
# ---> This plot shows the relationship between the cooling capacity of air conditioners and their prices.
#
# ---> Each point represents an air conditioner, with its position determined by its cooling capacity and price.
#
# ---> The color of the points indicates the star rating of the air conditioner, with blue representing lower star ratings and red representing higher star ratings.
#
# ---> The plot suggests that air conditioners with higher cooling capacities (around 2.0 tons) tend to have higher prices.
#
# ---> There is a clustering of prices around certain cooling capacities (e.g., 1.0 ton, 1.4 tons, and 2.0 tons).
#
# ---> Higher star ratings (4 and 5 stars) are more frequently associated with higher prices.

# %% [markdown]
# ### Ratings vs. Reviews Distributions (scatterplot)

# %%
sns.scatterplot(data=data, x="Ratings", y="Reviews", hue="Star_Rating", palette="deep", alpha=0.7)
plt.title("Ratings vs. Reviews")
plt.show()

# %% [markdown]
# ### Observations
# ---> The scatter plot shows the relationship between the ratings of air conditioners and the number of reviews they have received.
#
# ---> Each point represents an air conditioner, with its position determined by its rating and the number of reviews.
#
# ---> The color of the points indicates the star rating of the air conditioner, with different colors representing different star ratings.
#
# ---> The plot suggests that higher ratings (around 4.0 to 4.2) tend to have a higher number of reviews, and most of the data points are concentrated in this range.

# %% [markdown]
# ### Pair Plot of Numerical Features with Star Rating Distributions (pairplot)

# %%
sns.pairplot(data, hue='Star_Rating', diag_kind='kde', palette='viridis')
plt.suptitle("Pair Plot of Numerical Features with Star Rating", y=1.02)
plt.savefig('Pair Plot of Numerical Features with Star Rating.png', bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# C:\Users\ramya vemuri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ramya vemuri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ramya vemuri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ### Price vs Ratings (Bubble Size = Reviews, Color = Star Rating) (scatterplot)

# %%
sns.scatterplot(data=data, x="Ratings", y="Price", size="Reviews", hue="Star_Rating", palette="viridis", alpha=0.7)
plt.title("Price vs Ratings (Bubble Size = Reviews, Color = Star Rating)")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.savefig('Price vs Ratings.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ### Observations
# ---> The plot shows that most products have ratings clustered around 4.0.
#
# ---> Higher-priced products tend to have higher ratings.
#
# ---> Products with more reviews (larger bubbles) are more likely to have higher ratings and prices.
#
# ---> The color distribution indicates that higher star ratings (4 and 5 stars) are more common among higher-priced products.

# %% [markdown]
# ### Price vs Ratings by Star Rating and Cooling Capacity (lmplot)

# %%
sns.lmplot(
    data=data, 
    x="Ratings", y="Price", col="Star_Rating", hue="Cooling_Capacity(Ton)", 
    palette="coolwarm", height=5, aspect=1)
plt.suptitle("Price vs Ratings by Star Rating and Cooling Capacity", y=1.02)
plt.show()

# %% [markdown]
# ---> Star Rating = 2: There is only one data point, making it difficult to draw any meaningful conclusions.
#
# ---> Star Rating = 3: There is a mix of cooling capacities, and the regression lines show different trends. For lower cooling capacities (blue), the price tends to decrease slightly with higher ratings. For higher cooling capacities (red), the price tends to increase with higher ratings.
#
# ---> Star Rating = 4: The data points are more clustered, and the regression lines show a slight increase in price with higher ratings for higher cooling capacities.
#
# ---> Star Rating = 5: The regression lines indicate that for higher cooling capacities, the price increases with higher ratings. For lower cooling capacities, the trend is less clear but generally shows a slight increase in price with higher ratings.

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# ### Bubble Plot: Price vs Annual Power Usage (Size = No. of Ratings) Distributions (scatterplot)

# %%
sns.scatterplot(
    data=data, 
    x="Annual_power_usage", y="Price", size="no_of_rating", hue="Star_Rating", 
    alpha=0.7, palette="Spectral", sizes=(50, 500)
)
plt.title("Bubble Plot: Price vs Annual Power Usage (Size = No. of Ratings)")
plt.savefig("Bubble Plot: Price vs Annual Power Usage (Size = No. of Ratings).png", bbox_inches="tight", pad_inches=0.1)
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %% [markdown]
#  ---> Annual Power Usage vs. Price: The plot shows the relationship between the annual power usage and the price of the items.
#
# ---> Bubble Size: Larger bubbles indicate items with more ratings, suggesting popularity or higher sales.
#
# ---> Bubble Color: The color coding helps to identify the star rating of each item, providing insights into the energy efficiency and quality of the items.

# %% [markdown]
# ## 3. Correlation Heatmap (Price, Ratings, Cooling Capacity, Power Usage)

# %%
correlation_matrix = data[['Price', 'Ratings', 'Cooling_Capacity(Ton)', 'Annual_power_usage']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='Purples', fmt='.2f')
plt.title('Correlation Heatmap')
plt.savefig('Correlation Heatmap.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ## Explanation of the Plot
# ### Price vs. Cooling_Capacity(Ton):
# There is a moderate positive correlation (0.58), indicating that as the cooling capacity increases, the price tends to increase as well.
# ### Price vs. Annual_power_usage:
# There is a weaker positive correlation (0.30), suggesting that higher-priced air conditioners tend to have higher annual power usage.
# ### Ratings:
# The ratings have very low correlations with the other variables, indicating that customer ratings are not strongly influenced by price, cooling capacity, or annual power usage.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Brand                  476 non-null    object
#  1   Cooling_Capacity(Ton)  476 non-null    float64
#  2   Star_Rating            476 non-null    int64
#  3   Annual_power_usage     476 non-null    float64
#  4   Average_Room_Size      476 non-null    float64
#  5   Warranty               476 non-null    float64
#  6   Price                  476 non-null    int64
#  7   Ratings                476 non-null    float64
#  8   no_of_rating           476 non-null    int64
#  9   Reviews                476 non-null    int64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 37.3+ KB
