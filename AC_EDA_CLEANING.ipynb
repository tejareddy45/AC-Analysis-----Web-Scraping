# %% [markdown]
# ### analyzing and identifying the best air conditioners available in flipkart based on their features and customer ratings and reviews.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\ramya vemuri\Downloads\AC_data.csv")

# %%
data
# Out:
#      Unnamed: 0    Brand Cooling_Capacity Star_Rating  Annual_power_usage  \
# 0             0      IFB            1 Ton      3 Star              655.74
# 1             1  CARRIER          1.5 Ton      3 Star              964.10
# 2             2   Godrej          1.5 Ton      3 Star              966.34
# 3             3   Godrej          1.4 Ton      3 Star              905.88
# 4             4     MarQ          1.5 Ton      3 Star              952.69
# ..          ...      ...              ...         ...                 ...
# 671         671     Blue            2 Ton      3 Star             1261.37
# 672         672    Haier          1.5 Ton      3 Star              925.24
# 673         673  SAMSUNG          1.5 Ton      5 Star              749.48
# 674         674  SAMSUNG          1.5 Ton      3 Star              977.80
# 675         675       LG          1.5 Ton      5 Star                 NaN
#
#      Room_Size  Warranty   Price  Ratings no_of_rating Reviews
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          676 non-null    int64
#  1   Brand               667 non-null    object
#  2   Cooling_Capacity    676 non-null    object
#  3   Star_Rating         664 non-null    object
#  4   Annual_power_usage  628 non-null    float64
#  5   Room_Size           672 non-null    object
#  6   Warranty            497 non-null    float64
#  7   Price               674 non-null    object
#  8   Ratings             587 non-null    float64
#  9   no_of_rating        539 non-null    object
#  10  Reviews             478 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 58.2+ KB

# %%
data.describe()
# Out:
#        Unnamed: 0  Annual_power_usage    Warranty     Ratings
# count  676.000000          628.000000  497.000000  587.000000
# mean   337.500000          881.529363    1.331992    3.995741
# std    195.288675          215.671937    1.083436    0.344284
# min      0.000000           68.400000    1.000000    1.500000
# 25%    168.750000          742.435000    1.000000    4.000000
# 50%    337.500000          876.760000    1.000000    4.000000
# 75%    506.250000         1002.830000    1.000000    4.100000
# max    675.000000         1464.720000    5.000000    5.000000

# %%
print(data.isnull().sum())
# Out:
# Unnamed: 0              0
# Brand                   9
# Cooling_Capacity        0
# Star_Rating            12
# Annual_power_usage     48
# Room_Size               4
# Warranty              179
# Price                   2
# Ratings                89
# no_of_rating          137
# Reviews               198
# dtype: int64

# %%
data["Brand"].unique()
# Out:
# array(['IFB', 'CARRIER', 'Godrej', 'MarQ', 'Daikin', 'Lloyd', 'Panasonic',
#        'LG', 'ONIDA', 'Blue', 'realme', 'Voltas', 'Haier', 'SAMSUNG',
#        'Whirlpool', 'Hisense', 'Hitachi', 'TOSHIBA', 'Midea', 'Admiral',
#        'Mitsubishi', 'MITASHI', nan, 'CANDY', 'MOTOROLA', 'Electrolux',
#        'Acer', 'Kelvinator', 'White', 'Frigidaire', 'Gazhal', 'iMEE',
#        'Equator'], dtype=object)

# %%
data["Brand"].value_counts()
# Out:
# Brand
# Panasonic     174
# Blue           98
# Godrej         56
# CARRIER        49
# Lloyd          39
# Voltas         38
# IFB            34
# Hitachi        33
# Daikin         32
# SAMSUNG        24
# Haier          22
# LG             15
# realme          6
# Whirlpool       6
# MarQ            6
# ONIDA           5
# Midea           4
# Admiral         3
# MITASHI         3
# Acer            3
# White           2
# Hisense         2
# iMEE            2
# Frigidaire      2
# TOSHIBA         2
# Gazhal          1
# Mitsubishi      1
# Kelvinator      1
# Electrolux      1
# MOTOROLA        1
# CANDY           1
# Equator         1
# Name: count, dtype: int64

# %%
data=data.drop(columns = ["Unnamed: 0"])

# %%
data
# Out:
#        Brand Cooling_Capacity Star_Rating  Annual_power_usage  Room_Size  \
# 0        IFB            1 Ton      3 Star              655.74        90
# 1    CARRIER          1.5 Ton      3 Star              964.10  111 - 150
# 2     Godrej          1.5 Ton      3 Star              966.34  111 - 150
# 3     Godrej          1.4 Ton      3 Star              905.88  111 - 150
# 4       MarQ          1.5 Ton      3 Star              952.69  111 - 150
# ..       ...              ...         ...                 ...        ...
# 671     Blue            2 Ton      3 Star             1261.37  151 - 200
# 672    Haier          1.5 Ton      3 Star              925.24  111 - 150
# 673  SAMSUNG          1.5 Ton      5 Star              749.48  111 - 150
# 674  SAMSUNG          1.5 Ton      3 Star              977.80  111 - 150
# 675       LG          1.5 Ton      5 Star                 NaN       520
#
#      Warranty   Price  Ratings no_of_rating Reviews
# ...

# %%
data
# Out:
#        Brand Cooling_Capacity Star_Rating  Annual_power_usage  Room_Size  \
# 0        IFB            1 Ton      3 Star              655.74        90
# 1    CARRIER          1.5 Ton      3 Star              964.10  111 - 150
# 2     Godrej          1.5 Ton      3 Star              966.34  111 - 150
# 3     Godrej          1.4 Ton      3 Star              905.88  111 - 150
# 4       MarQ          1.5 Ton      3 Star              952.69  111 - 150
# ..       ...              ...         ...                 ...        ...
# 671     Blue            2 Ton      3 Star             1261.37  151 - 200
# 672    Haier          1.5 Ton      3 Star              925.24  111 - 150
# 673  SAMSUNG          1.5 Ton      5 Star              749.48  111 - 150
# 674  SAMSUNG          1.5 Ton      3 Star              977.80  111 - 150
# 675       LG          1.5 Ton      5 Star                 NaN       520
#
#      Warranty   Price  Ratings no_of_rating Reviews
# ...

# %%
datac = data.copy()

# %%
datac
# Out:
#        Brand Cooling_Capacity Star_Rating  Annual_power_usage  Room_Size  \
# 0        IFB            1 Ton      3 Star              655.74        90
# 1    CARRIER          1.5 Ton      3 Star              964.10  111 - 150
# 2     Godrej          1.5 Ton      3 Star              966.34  111 - 150
# 3     Godrej          1.4 Ton      3 Star              905.88  111 - 150
# 4       MarQ          1.5 Ton      3 Star              952.69  111 - 150
# ..       ...              ...         ...                 ...        ...
# 671     Blue            2 Ton      3 Star             1261.37  151 - 200
# 672    Haier          1.5 Ton      3 Star              925.24  111 - 150
# 673  SAMSUNG          1.5 Ton      5 Star              749.48  111 - 150
# 674  SAMSUNG          1.5 Ton      3 Star              977.80  111 - 150
# 675       LG          1.5 Ton      5 Star                 NaN       520
#
#      Warranty   Price  Ratings no_of_rating Reviews
# ...

# %%
datac = datac.dropna(subset=["Brand","Price","Ratings","no_of_rating","Reviews"]).reset_index(drop=True)

# %%
datac
# Out:
#          Brand Cooling_Capacity Star_Rating  Annual_power_usage  Room_Size  \
# 0          IFB            1 Ton      3 Star              655.74        90
# 1      CARRIER          1.5 Ton      3 Star              964.10  111 - 150
# 2       Godrej          1.5 Ton      3 Star              966.34  111 - 150
# 3       Godrej          1.4 Ton      3 Star              905.88  111 - 150
# 4         MarQ          1.5 Ton      3 Star              952.69  111 - 150
# ..         ...              ...         ...                 ...        ...
# 472     Godrej            2 Ton      3 Star             1183.20  151 - 200
# 473  Panasonic          0.8 Ton      3 Star              519.64        90
# 474  Panasonic            1 Ton      3 Star              676.64        90
# 475       Blue            2 Ton      3 Star             1261.37  151 - 200
# 476         LG          1.5 Ton      5 Star                 NaN       520
#
#      Warranty   Price  Ratings no_of_rating Reviews
# ...

# %%
print(datac.isnull().sum())
# Out:
# Brand                   0
# Cooling_Capacity        0
# Star_Rating             0
# Annual_power_usage      9
# Room_Size               1
# Warranty              122
# Price                   0
# Ratings                 0
# no_of_rating            0
# Reviews                 0
# dtype: int64

# %%
# Replace NaN with 0 in specific columns
datac[['Annual_power_usage','Warranty', 'Ratings', 'no_of_rating', 'Reviews']] = datac[['Annual_power_usage','Warranty', 'Ratings', 'no_of_rating', 'Reviews']].fillna(0)

# %%
datac
# Out:
#          Brand Cooling_Capacity Star_Rating  Annual_power_usage  Room_Size  \
# 0          IFB            1 Ton      3 Star              655.74        90
# 1      CARRIER          1.5 Ton      3 Star              964.10  111 - 150
# 2       Godrej          1.5 Ton      3 Star              966.34  111 - 150
# 3       Godrej          1.4 Ton      3 Star              905.88  111 - 150
# 4         MarQ          1.5 Ton      3 Star              952.69  111 - 150
# ..         ...              ...         ...                 ...        ...
# 472     Godrej            2 Ton      3 Star             1183.20  151 - 200
# 473  Panasonic          0.8 Ton      3 Star              519.64        90
# 474  Panasonic            1 Ton      3 Star              676.64        90
# 475       Blue            2 Ton      3 Star             1261.37  151 - 200
# 476         LG          1.5 Ton      5 Star                0.00       520
#
#      Warranty   Price  Ratings no_of_rating Reviews
# ...

# %%
datac
# Out:
#          Brand Cooling_Capacity Star_Rating  Annual_power_usage  Room_Size  \
# 0          IFB            1 Ton      3 Star              655.74        90
# 1      CARRIER          1.5 Ton      3 Star              964.10  111 - 150
# 2       Godrej          1.5 Ton      3 Star              966.34  111 - 150
# 3       Godrej          1.4 Ton      3 Star              905.88  111 - 150
# 4         MarQ          1.5 Ton      3 Star              952.69  111 - 150
# ..         ...              ...         ...                 ...        ...
# 472     Godrej            2 Ton      3 Star             1183.20  151 - 200
# 473  Panasonic          0.8 Ton      3 Star              519.64        90
# 474  Panasonic            1 Ton      3 Star              676.64        90
# 475       Blue            2 Ton      3 Star             1261.37  151 - 200
# 476         LG          1.5 Ton      5 Star                0.00       520
#
#      Warranty   Price  Ratings no_of_rating Reviews
# ...

# %%
datac = datac.dropna(subset=['Room_Size']).reset_index(drop=True)

# %%
datac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Brand               476 non-null    object
#  1   Cooling_Capacity    476 non-null    object
#  2   Star_Rating         476 non-null    object
#  3   Annual_power_usage  476 non-null    float64
#  4   Room_Size           476 non-null    object
#  5   Warranty            476 non-null    float64
#  6   Price               476 non-null    object
#  7   Ratings             476 non-null    float64
#  8   no_of_rating        476 non-null    object
#  9   Reviews             476 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 37.3+ KB

# %% [markdown]
# ### Calculating the average room size

# %%
def calculate_average_room_size(value):
    # Check if the room size is a range (contains ' - ')
    if isinstance(value, str) and ' - ' in value:
        start, end = value.split(' - ')
        return (float(start) + float(end)) / 2  # Average of the range
    else:
        return float(value)  # Single value

# Applying the function to the 'Room_Size' column to get average room size for each row
datac['Average_Room_Size'] = datac['Room_Size'].apply(calculate_average_room_size)

# Display the updated DataFrame with the new 'Average_Room_Size' column
datac = datac[['Brand', 'Cooling_Capacity', 'Star_Rating', 'Annual_power_usage', 'Room_Size', 'Average_Room_Size', 'Warranty', 'Price', 'Ratings', 'no_of_rating', 'Reviews']]

# %%
datac
# Out:
#          Brand Cooling_Capacity Star_Rating  Annual_power_usage  Room_Size  \
# 0          IFB            1 Ton      3 Star              655.74        90
# 1      CARRIER          1.5 Ton      3 Star              964.10  111 - 150
# 2       Godrej          1.5 Ton      3 Star              966.34  111 - 150
# 3       Godrej          1.4 Ton      3 Star              905.88  111 - 150
# 4         MarQ          1.5 Ton      3 Star              952.69  111 - 150
# ..         ...              ...         ...                 ...        ...
# 471     Godrej            2 Ton      3 Star             1183.20  151 - 200
# 472  Panasonic          0.8 Ton      3 Star              519.64        90
# 473  Panasonic            1 Ton      3 Star              676.64        90
# 474       Blue            2 Ton      3 Star             1261.37  151 - 200
# 475         LG          1.5 Ton      5 Star                0.00       520
#
#      Average_Room_Size  Warranty   Price  Ratings no_of_rating Reviews
# ...

# %% [markdown]
# ### Removing 'Star' from the 'Star_Rating' column

# %%
datac['Star_Rating'] = datac['Star_Rating'].str.replace(' Star', '', regex=False)

# %% [markdown]
# ### Removing 'Ton' from the 'Cooling_Capacity' column

# %%
datac['Cooling_Capacity'] = datac['Cooling_Capacity'].str.replace(' Ton', '', regex=False)

# %%
datac
# Out:
#          Brand Cooling_Capacity Star_Rating  Annual_power_usage  Room_Size  \
# 0          IFB                1           3              655.74        90
# 1      CARRIER              1.5           3              964.10  111 - 150
# 2       Godrej              1.5           3              966.34  111 - 150
# 3       Godrej              1.4           3              905.88  111 - 150
# 4         MarQ              1.5           3              952.69  111 - 150
# ..         ...              ...         ...                 ...        ...
# 471     Godrej                2           3             1183.20  151 - 200
# 472  Panasonic              0.8           3              519.64        90
# 473  Panasonic                1           3              676.64        90
# 474       Blue                2           3             1261.37  151 - 200
# 475         LG              1.5           5                0.00       520
#
#      Average_Room_Size  Warranty   Price  Ratings no_of_rating Reviews
# ...

# %%
datac = datac[['Brand', 'Cooling_Capacity', 'Star_Rating', 'Annual_power_usage', 'Average_Room_Size', 'Warranty', 'Price', 'Ratings', 'no_of_rating', 'Reviews']]

# %%
datac
# Out:
#          Brand Cooling_Capacity Star_Rating  Annual_power_usage  \
# 0          IFB                1           3              655.74
# 1      CARRIER              1.5           3              964.10
# 2       Godrej              1.5           3              966.34
# 3       Godrej              1.4           3              905.88
# 4         MarQ              1.5           3              952.69
# ..         ...              ...         ...                 ...
# 471     Godrej                2           3             1183.20
# 472  Panasonic              0.8           3              519.64
# 473  Panasonic                1           3              676.64
# 474       Blue                2           3             1261.37
# 475         LG              1.5           5                0.00
#
#      Average_Room_Size  Warranty   Price  Ratings no_of_rating Reviews
# 0                 90.0       0.0  29,990      3.9        1,637     133
# ...

# %% [markdown]
# ### renaming the dataframe

# %%
datac=datac.rename(columns={"Brand":"Brand","Cooling_Capacity":"Cooling_Capacity(Ton)","Star_Rating":"Star_Rating","Annual_power_usage":"Annual_power_usage","Average_Room_Size":"Average_Room_Size","Warranty":"Warranty","Price":"Price","Ratings":"Ratings","No_of_Rating":"no_of_rating","reviews":"Reviews"})

# %%
datac
# Out:
#          Brand Cooling_Capacity(Ton) Star_Rating  Annual_power_usage  \
# 0          IFB                     1           3              655.74
# 1      CARRIER                   1.5           3              964.10
# 2       Godrej                   1.5           3              966.34
# 3       Godrej                   1.4           3              905.88
# 4         MarQ                   1.5           3              952.69
# ..         ...                   ...         ...                 ...
# 471     Godrej                     2           3             1183.20
# 472  Panasonic                   0.8           3              519.64
# 473  Panasonic                     1           3              676.64
# 474       Blue                     2           3             1261.37
# 475         LG                   1.5           5                0.00
#
#      Average_Room_Size  Warranty   Price  Ratings no_of_rating Reviews
# ...

# %% [markdown]
# ### changing the dtypes

# %%
datac["Price"] = datac["Price"].replace({",":""},regex = True)
datac["no_of_rating"] = datac["no_of_rating"].replace({",":""},regex = True)
datac["Reviews"] = datac["Reviews"].replace({",":""},regex = True)

# %%
# Converting to float
#datac['Cooling_Capacity(Ton)'] = datac['Cooling_Capacity(Ton)'].astype(float)
# Converting to int
datac['Star_Rating'] = datac['Star_Rating'].astype(int)
# Converting to float
datac['Annual_power_usage'] = datac['Annual_power_usage'].astype(float)
# Keep as string, for handling ranges
#datac['Room_Size'] = datac['Room_Size'].astype(str)
# Converting to float
datac['Average_Room_Size'] = datac['Average_Room_Size'].astype(float)
# Converting to float
datac['Warranty'] = datac['Warranty'].astype(float)
# Converting to int
datac['Price'] = datac['Price'].astype(int)
# Converting to float
datac['Ratings'] = datac['Ratings'].astype(float)
# Converting to int
datac['no_of_rating'] = datac['no_of_rating'].astype(int)
# Converting to int
datac['Reviews'] = datac['Reviews'].astype(int)

# %%
datac["Cooling_Capacity(Ton)"]= datac["Cooling_Capacity(Ton)"].astype(float)

# %%
print(datac.isnull().sum())
# Out:
# Brand                    0
# Cooling_Capacity(Ton)    0
# Star_Rating              0
# Annual_power_usage       0
# Average_Room_Size        0
# Warranty                 0
# Price                    0
# Ratings                  0
# no_of_rating             0
# Reviews                  0
# dtype: int64

# %%
datac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Brand                  476 non-null    object
#  1   Cooling_Capacity(Ton)  476 non-null    float64
#  2   Star_Rating            476 non-null    int32
#  3   Annual_power_usage     476 non-null    float64
#  4   Average_Room_Size      476 non-null    float64
#  5   Warranty               476 non-null    float64
#  6   Price                  476 non-null    int32
#  7   Ratings                476 non-null    float64
#  8   no_of_rating           476 non-null    int32
#  9   Reviews                476 non-null    int32
# dtypes: float64(5), int32(4), object(1)
# memory usage: 29.9+ KB

# %%
datac.to_csv(r"C:\Users\ramya vemuri\Downloads\AC_Cleaning.csv")
